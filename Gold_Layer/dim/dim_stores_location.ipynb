# %%
# %sql
CREATE OR REPLACE TABLE electronics_retailer_clg.gold.dim_stores AS
SELECT 
  storekey,
  country,
  CASE 
    WHEN storekey = 0 THEN 'Online'
    ELSE 'In-Store'
  END as channel
FROM electronics_retailer_clg.silver.stores;
