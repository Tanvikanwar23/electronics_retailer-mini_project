# %%
# %sql
CREATE OR REPLACE TABLE electronics_retailer_clg.gold.dim_products AS
select 
  productkey,
  product_name,
  brand,
  color,
  category,
  subcategory,
  unit_price_usd
FROM electronics_retailer_clg.silver.products;

# %%
# %sql
select * from electronics_retailer_clg.gold.dim_products
