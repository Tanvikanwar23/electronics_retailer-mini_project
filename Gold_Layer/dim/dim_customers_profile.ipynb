-- %%
%sql
CREATE OR REPLACE TABLE electronics_retailer_clg.gold.dim_customers AS
select 
  customerkey,
  gender,
  continent,
  country,
  state,
  city 
FROM electronics_retailer_clg.silver.customers;

-- %%
select * from electronics_retailer_clg.gold.dim_customers;
