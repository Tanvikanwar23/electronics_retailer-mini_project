# %%
 # Read CSV from CUSTOMERS
 
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("s3a://databricks-project-jman/electronics_retailer/Customers.csv")


df = df.toDF(*[col.replace(" ", "_") for col in df.columns])

# Unity Catalog details
catalog_name = "electronics_retailer_clg"
schema_name = "default"
table_name = "customers"


# Save as table
df.write.mode("overwrite").saveAsTable(f"{catalog_name}.{schema_name}.{table_name}")


print(f"Table created: {catalog_name}.{schema_name}.{table_name}")

# %%
 # Read CSV from DATA DICTIONARY
 
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("s3://databricks-project-jman/electronics_retailer/Data_Dictionary.csv")

# Unity Catalog details
catalog_name = "electronics_retailer_clg"
schema_name = "default"
table_name = "data_dictionary"


# Save as table
df.write.mode("overwrite").saveAsTable(f"{catalog_name}.{schema_name}.{table_name}")


print(f"Table created: {catalog_name}.{schema_name}.{table_name}")

# %%
 # Read CSV from EXCHANGE RATES
 
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("s3://databricks-project-jman/electronics_retailer/Exchange_Rates.csv")

# Unity Catalog details
catalog_name = "electronics_retailer_clg"
schema_name = "default"
table_name = "exchange_rates"


# Save as table
df.write.mode("overwrite").saveAsTable(f"{catalog_name}.{schema_name}.{table_name}")


print(f"Table created: {catalog_name}.{schema_name}.{table_name}")

# %%
# Read CSV from PRODUCTS
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("s3a://databricks-project-jman/electronics_retailer/Products.csv")

df = df.toDF(*[c.replace(" ", "_") for c in df.columns])


# Unity Catalog details
catalog_name = "electronics_retailer_clg"
schema_name = "default"
table_name = "products"


# Save as table
df.write.mode("overwrite").saveAsTable(f"{catalog_name}.{schema_name}.{table_name}")


print(f"Table created: {catalog_name}.{schema_name}.{table_name}")

# %%
 # Read CSV from SALES

 
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("s3://databricks-project-jman/electronics_retailer/Sales.csv")

df = df.toDF(*[c.replace(" ", "_") for c in df.columns])

# Unity Catalog details
catalog_name = "electronics_retailer_clg"
schema_name = "default"
table_name = "sales"


# Save as table
df.write.mode("overwrite").saveAsTable(f"{catalog_name}.{schema_name}.{table_name}")


print(f"Table created: {catalog_name}.{schema_name}.{table_name}")

# %%
 # Read CSV from STORES

 
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("s3://databricks-project-jman/electronics_retailer/Stores.csv")

df = df.toDF(*[c.replace(" ", "_") for c in df.columns])

# Unity Catalog details
catalog_name = "electronics_retailer_clg"
schema_name = "default"
table_name = "storeelectronics_retailer_clg.default.store"


# Save as table
df.write.mode("overwrite").saveAsTable(f"{catalog_name}.{schema_name}.{table_name}")


print(f"Table created: {catalog_name}.{schema_name}.{table_name}")
